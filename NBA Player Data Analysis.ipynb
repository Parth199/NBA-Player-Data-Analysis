# %%
import pandas as pd

# %%
nba=pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
rev=pd.read_csv("revenue.csv",index_col="Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
rev.sum(axis=1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba["Name"] #getting a single column values
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba[["Name","Height"]] #selecting two or more columns in a dataframe
# Out:
#               Name Height
# 0    Avery Bradley    6-2
# 1      Jae Crowder    6-6
# 2     John Holland    6-5
# 3      R.J. Hunter    6-5
# 4    Jonas Jerebko   6-10
# ..             ...    ...
# 453   Shelvin Mack    6-3
# 454      Raul Neto    6-1
# 455   Tibor Pleiss    7-3
# 456    Jeff Withey    7-0
# 457            NaN    NaN
#
# [458 rows x 2 columns]

# %%
nba["Sports"]="Basketball" #inserting a new column in dataframe

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary      Sports
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba=pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.insert(3,column="Sport",value="Basketball")

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN

# %%
nba["Weight in kilograms"]=nba.Weight.mul(0.453592) #broadcasting the values

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kilograms
# 0              Texas  7730337.0             81.64656
# 1          Marquette  6796117.0            106.59412
# 2  Boston University        NaN             92.98636

# %%
nba.Team()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-e8c4a51c9343> in <module>
# ----> 1 nba.Team()
#
# TypeError: 'Series' object is not callable

# %%
nba["Team"].value_counts()
nba["Position"].value_counts().head(1)
nba["Salary"].value_counts().tail(1)
# Out:
# 700902.0    1
# Name: Salary, dtype: int64

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kilograms
# 0              Texas  7730337.0             81.64656
# 1          Marquette  6796117.0            106.59412
# 2  Boston University        NaN             92.98636

# %%
nba["Salary"].dropna()
# Out:
# 0       7730337.0
# 1       6796117.0
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
#           ...
# 452     2239800.0
# 453     2433333.0
# 454      900000.0
# 455     2900000.0
# 456      947276.0
# Name: Salary, Length: 446, dtype: float64

# %%
nba.head()
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary  Weight in kilograms
# 453  2433333.0            92.079176
# 454   900000.0            81.192968
# 455  2900000.0           116.119552
# 456   947276.0           104.779752
# 457        NaN                  NaN

# %%
nba.dropna() #drop the null value from the entire dataframe
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Weight in kilograms
# ...

# %%
nba.dropna(how="all",inplace=True) #remove the row in which every value in null

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary  Weight in kilograms
# 454   900000.0            81.192968
# 455  2900000.0           116.119552
# 456   947276.0           104.779752

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kilograms
# 0              Texas  7730337.0             81.64656
# 1          Marquette  6796117.0            106.59412
# 2  Boston University        NaN             92.98636

# %%
nba.dropna(axis=1) #remove the column which has a null value
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#      Weight in kilograms
# 0              81.646560
# 1             106.594120
# ...

# %%
nba.dropna(subset=["Salary","College"]) #remove the null value in college and salary column
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Weight in kilograms
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kilograms
# 0              Texas  7730337.0             81.64656
# 1          Marquette  6796117.0            106.59412
# 2  Boston University        NaN             92.98636

# %%
nba["Salary"].fillna(0,inplace=True)

# %%
nba["College"].fillna("No College",inplace=True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in kilograms
# 0              Texas  7730337.0            81.646560
# 1          Marquette  6796117.0           106.594120
# 2  Boston University        0.0            92.986360
# 3      Georgia State  1148640.0            83.914520
# 4         No College  5000000.0           104.779752

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 457 non-null    object
#  1   Team                 457 non-null    object
#  2   Number               457 non-null    float64
#  3   Position             457 non-null    object
#  4   Age                  457 non-null    float64
#  5   Height               457 non-null    object
#  6   Weight               457 non-null    float64
#  7   College              457 non-null    object
#  8   Salary               457 non-null    float64
#  9   Weight in kilograms  457 non-null    float64
# dtypes: float64(5), object(5)
# memory usage: 39.3+ KB

# %%
nba["Salary"]=nba["Salary"].astype("int") #converting salary float datatype to int

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Weight in kilograms
# 0              Texas  7730337             81.64656
# 1          Marquette  6796117            106.59412
# 2  Boston University        0             92.98636

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 457 non-null    object
#  1   Team                 457 non-null    object
#  2   Number               457 non-null    float64
#  3   Position             457 non-null    object
#  4   Age                  457 non-null    float64
#  5   Height               457 non-null    object
#  6   Weight               457 non-null    float64
#  7   College              457 non-null    object
#  8   Salary               457 non-null    int32
#  9   Weight in kilograms  457 non-null    float64
# dtypes: float64(4), int32(1), object(5)
# memory usage: 37.5+ KB

# %%
nba["Number"]=nba["Number"].astype("int")

# %%
nba["Age"]=nba["Age"].astype("int")

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10   231.0
#
#              College   Salary  Weight in kilograms
# 0              Texas  7730337            81.646560
# 1          Marquette  6796117           106.594120
# 2  Boston University        0            92.986360
# 3      Georgia State  1148640            83.914520
# 4         No College  5000000           104.779752

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 457 non-null    object
#  1   Team                 457 non-null    object
#  2   Number               457 non-null    int32
#  3   Position             457 non-null    object
#  4   Age                  457 non-null    int32
#  5   Height               457 non-null    object
#  6   Weight               457 non-null    float64
#  7   College              457 non-null    object
#  8   Salary               457 non-null    int32
#  9   Weight in kilograms  457 non-null    float64
# dtypes: float64(2), int32(3), object(5)
# memory usage: 33.9+ KB

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"]=nba["Position"].astype("category") #category is used if there are similar type to values in a column like for position it has 5 distinct values so to reduce the memory space we used category

# %%
nba["Team"]=nba["Team"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 457 non-null    object
#  1   Team                 457 non-null    category
#  2   Number               457 non-null    int32
#  3   Position             457 non-null    category
#  4   Age                  457 non-null    int32
#  5   Height               457 non-null    object
#  6   Weight               457 non-null    float64
#  7   College              457 non-null    object
#  8   Salary               457 non-null    int32
#  9   Weight in kilograms  457 non-null    float64
# dtypes: category(2), float64(2), int32(3), object(3)
# memory usage: 29.3+ KB

# %%
nba.sort_values("Salary",ascending=False,na_position='first') #sorting the values with highest salary
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers      24       SF   37    6-6
# 169     LeBron James     Cleveland Cavaliers      23       SF   31    6-8
# 33   Carmelo Anthony         New York Knicks       7       SF   32    6-8
# 251    Dwight Howard         Houston Rockets      12        C   30   6-11
# 339       Chris Bosh              Miami Heat       1       PF   32   6-11
# ..               ...                     ...     ...      ...  ...    ...
# 353    Dorell Wright              Miami Heat      11       SF   30    6-9
# 264    Jordan Farmar       Memphis Grizzlies       4       PG   29    6-2
# 409       Greg Smith  Minnesota Timberwolves       4       PF   25   6-10
# 273   Alex Stepheson       Memphis Grizzlies      35       PF   28   6-10
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
#
#      Weight       College    Salary  Weight in kilograms
# ...

# %%
nba.sort_values(["Team","Number"],ascending=[True,False]) #sorting with multiple columns
# Out:
#                 Name                Team  Number Position  Age Height  Weight  \
# 313   Kris Humphries       Atlanta Hawks      43       PF   31    6-9   235.0
# 319       Mike Scott       Atlanta Hawks      32       PF   27    6-8   237.0
# 316     Mike Muscala       Atlanta Hawks      31       PF   24   6-11   240.0
# 314      Kyle Korver       Atlanta Hawks      26       SG   35    6-7   212.0
# 320  Thabo Sefolosha       Atlanta Hawks      25       SF   32    6-7   220.0
# ..               ...                 ...     ...      ...  ...    ...     ...
# 368    Alan Anderson  Washington Wizards       6       SG   33    6-6   220.0
# 376  Markieff Morris  Washington Wizards       5       PF   26   6-10   245.0
# 369     Bradley Beal  Washington Wizards       3       SG   22    6-5   207.0
# 382        John Wall  Washington Wizards       2       PG   25    6-4   195.0
# 370     Jared Dudley  Washington Wizards       1       SF   30    6-7   225.0
#
# ...

# %%
nba["Salary Rank"]=nba["Salary"].rank(ascending=False).astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary  Weight in kilograms  Salary Rank
# 0              Texas  7730337             81.64656           97
# 1          Marquette  6796117            106.59412          110
# 2  Boston University        0             92.98636          452

# %%
nba.sort_values("Salary",ascending=False)
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers      24       SF   37    6-6
# 169     LeBron James     Cleveland Cavaliers      23       SF   31    6-8
# 33   Carmelo Anthony         New York Knicks       7       SF   32    6-8
# 251    Dwight Howard         Houston Rockets      12        C   30   6-11
# 339       Chris Bosh              Miami Heat       1       PF   32   6-11
# ..               ...                     ...     ...      ...  ...    ...
# 353    Dorell Wright              Miami Heat      11       SF   30    6-9
# 264    Jordan Farmar       Memphis Grizzlies       4       PG   29    6-2
# 409       Greg Smith  Minnesota Timberwolves       4       PF   25   6-10
# 273   Alex Stepheson       Memphis Grizzlies      35       PF   28   6-10
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
#
#      Weight       College    Salary  Weight in kilograms  Salary Rank
# ...
